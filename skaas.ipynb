# %% [markdown]
# # Calculating the performance

# %% [markdown]
# Silhouette score is used to evaluate the quality of clusters created using the K-Means clustering algorithm.This measure has a range of [-1, 1].To calculate the Silhouette score for each observation/data point, the following distances need to be found out for each observations belonging to all the clusters:
#
#    1.Mean distance between the observation and all other data points in the same cluster. This distance can also be called a mean intra-cluster distance. The mean distance is denoted by "a".
#
#    2.Mean distance between the observation and all other data points of the next nearest cluster. This distance can also be called a mean nearest-cluster distance. The mean distance is denoted by "b"

# %% [markdown]
# ### Packages Required

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import glob
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ### Importing multiple files using os and glob

# %% [markdown]
# The glob module is used here to retrive csv file names matching the specified pattern.

# %%
path="C://Users/Home/sample-dataset/ant-1.3"
read_files=glob.glob(os.path.join(path,"*.csv"))

# %%
read_files[:5]
# Out:
# ['C://Users/Home/sample-dataset/ant-1.3\\ant-1.3.csv',
#  'C://Users/Home/sample-dataset/ant-1.3\\ant-1.4.csv',
#  'C://Users/Home/sample-dataset/ant-1.3\\ant-1.5.csv',
#  'C://Users/Home/sample-dataset/ant-1.3\\ant-1.6.csv',
#  'C://Users/Home/sample-dataset/ant-1.3\\ant-1.7.csv']

# %% [markdown]
# ### Calculating Silhouette Score

# %% [markdown]
# A range of candidate values of k (number of clusters) is picked [2,3,4,5,6,7,8] and then trained using K-Means clustering for each of the values of k. For each k-Means clustering model the average silhouette coefficient is calculated.A high value indicates that the object is well matched to its own cluster and poorly matched to neighboring clusters(High inter cluster distance and low intra cluster distance).

# %%
def calculateSilhoutteScore(x,target):
    max_val=-1
    range_n_clusters = [2,3,4,5,6,7,8]
    row_list=[]
    row_list.append(target)
    for n_clusters in range_n_clusters:
        
        clusterer = KMeans(n_clusters=n_clusters, random_state=10)
        cluster_labels = clusterer.fit_predict(x)
        silhouette_avg = silhouette_score(x, cluster_labels)
        if(silhouette_avg>max_val):
            k=n_clusters
            max_val=silhouette_avg
        print("For n_clusters =",n_clusters, "The average silhouette_score is :", silhouette_avg)
        row_list.append(round(silhouette_avg,4))
    #print("Best k-value",k)
    #print(row_list)
    
    return k,row_list

# %%
df_list=[]

for files in read_files:
    data=pd.read_csv(files)
    x=data.iloc[:,3:]
    target=data.iloc[0,0]+"-"+str(data.iloc[0,1])
    print("Project: ",target)
    n_cluster,row_list=calculateSilhoutteScore(x,target)
    df_list.append(row_list)
    KMean= KMeans(n_clusters=n_cluster)
    KMean.fit(x)
    label=KMean.predict(x)
    
    
    print("----------------")
# Out:
# Project:  ant-1.3
# For n_clusters = 2 The average silhouette_score is : 0.867656262723419
# For n_clusters = 3 The average silhouette_score is : 0.6449335120984063
# For n_clusters = 4 The average silhouette_score is : 0.6260178768500043
# For n_clusters = 5 The average silhouette_score is : 0.5733877763741747
# For n_clusters = 6 The average silhouette_score is : 0.5651878315778446
# For n_clusters = 7 The average silhouette_score is : 0.5716345889622133
# For n_clusters = 8 The average silhouette_score is : 0.4618421135202239
# ----------------
# Project:  ant-1.4
# For n_clusters = 2 The average silhouette_score is : 0.6909507763284335
# For n_clusters = 3 The average silhouette_score is : 0.6535662481960056
# For n_clusters = 4 The average silhouette_score is : 0.6517469430248358
# For n_clusters = 5 The average silhouette_score is : 0.6640923576900749
# For n_clusters = 6 The average silhouette_score is : 0.5986950664576589
# For n_clusters = 7 The average silhouette_score is : 0.5042445125615287
# For n_clusters = 8 The average silhouette_score is : 0.4948690005889558
# ----------------
# Project:  ant-1.5
# For n_clusters = 2 The average silhouette_score is : 0.7950760318021967
# For n_clusters = 3 The average silhouette_score is : 0.7194231794067749
# For n_clusters = 4 The average silhouette_score is : 0.7118832513629126
# For n_clusters = 5 The average silhouette_score is : 0.6651045898844378
# For n_clusters = 6 The average silhouette_score is : 0.660180597036583
# For n_clusters = 7 The average silhouette_score is : 0.5671126727650796
# For n_clusters = 8 The average silhouette_score is : 0.5768365744846107
# ----------------
# Project:  ant-1.6
# For n_clusters = 2 The average silhouette_score is : 0.7497445547451426
# For n_clusters = 3 The average silhouette_score is : 0.7335502838859206
# For n_clusters = 4 The average silhouette_score is : 0.6731820071599507
# For n_clusters = 5 The average silhouette_score is : 0.6710350144505932
# For n_clusters = 6 The average silhouette_score is : 0.5979642132165833
# For n_clusters = 7 The average silhouette_score is : 0.6012936957064375
# For n_clusters = 8 The average silhouette_score is : 0.6002763592986707
# ----------------
# Project:  ant-1.7
# For n_clusters = 2 The average silhouette_score is : 0.7940928135860401
# For n_clusters = 3 The average silhouette_score is : 0.7678282981633447
# For n_clusters = 4 The average silhouette_score is : 0.699883164918575
# For n_clusters = 5 The average silhouette_score is : 0.5783483520937387
# For n_clusters = 6 The average silhouette_score is : 0.5785490431723432
# For n_clusters = 7 The average silhouette_score is : 0.5807979610915914
# For n_clusters = 8 The average silhouette_score is : 0.5813371967682277
# ----------------
# Project:  ArcPlatform-1
# For n_clusters = 2 The average silhouette_score is : 0.8035945257900005
# For n_clusters = 3 The average silhouette_score is : 0.7668393686718239
# For n_clusters = 4 The average silhouette_score is : 0.7455538491298361
# For n_clusters = 5 The average silhouette_score is : 0.5646139506972339
# For n_clusters = 6 The average silhouette_score is : 0.5624641779398393
# For n_clusters = 7 The average silhouette_score is : 0.5504399737256247
# For n_clusters = 8 The average silhouette_score is : 0.5350645985842013
# ----------------
# Project:  Berek-1
# For n_clusters = 2 The average silhouette_score is : 0.8901220352023892
# For n_clusters = 3 The average silhouette_score is : 0.6676036811621887
# For n_clusters = 4 The average silhouette_score is : 0.6425765115635852
# For n_clusters = 5 The average silhouette_score is : 0.6360909718201817
# For n_clusters = 6 The average silhouette_score is : 0.6175159952857057
# For n_clusters = 7 The average silhouette_score is : 0.6333173873089055
# For n_clusters = 8 The average silhouette_score is : 0.5991044142380695
# ----------------
# Project:  camel-1
# For n_clusters = 2 The average silhouette_score is : 0.9022705041986929
# For n_clusters = 3 The average silhouette_score is : 0.7299118269616366
# For n_clusters = 4 The average silhouette_score is : 0.7051035511683964
# For n_clusters = 5 The average silhouette_score is : 0.5564884078879896
# For n_clusters = 6 The average silhouette_score is : 0.5626679945365057
# For n_clusters = 7 The average silhouette_score is : 0.5344843805946439
# For n_clusters = 8 The average silhouette_score is : 0.5351360246912148
# ----------------
# Project:  camel-1.2
# For n_clusters = 2 The average silhouette_score is : 0.9538472587761324
# For n_clusters = 3 The average silhouette_score is : 0.846371655340031
# For n_clusters = 4 The average silhouette_score is : 0.6386881216838257
# For n_clusters = 5 The average silhouette_score is : 0.6153049054022292
# For n_clusters = 6 The average silhouette_score is : 0.5597488585709556
# For n_clusters = 7 The average silhouette_score is : 0.5622568205670856
# For n_clusters = 8 The average silhouette_score is : 0.5011561534781573
# ----------------
# Project:  camel-1.4
# For n_clusters = 2 The average silhouette_score is : 0.975592874298514
# For n_clusters = 3 The average silhouette_score is : 0.8613416258615563
# For n_clusters = 4 The average silhouette_score is : 0.6503553803972554
# For n_clusters = 5 The average silhouette_score is : 0.6492258200989787
# For n_clusters = 6 The average silhouette_score is : 0.646220013542321
# For n_clusters = 7 The average silhouette_score is : 0.6490335106611069
# For n_clusters = 8 The average silhouette_score is : 0.5816652279156865
# ----------------
# Project:  camel-1.6
# For n_clusters = 2 The average silhouette_score is : 0.978399473533383
# For n_clusters = 3 The average silhouette_score is : 0.9036736950743017
# For n_clusters = 4 The average silhouette_score is : 0.8748424348598467
# For n_clusters = 5 The average silhouette_score is : 0.7175771893047971
# For n_clusters = 6 The average silhouette_score is : 0.6227033347398901
# For n_clusters = 7 The average silhouette_score is : 0.596594743194629
# For n_clusters = 8 The average silhouette_score is : 0.5882777207841815
# ----------------
# Project:  E-Learning-1
# For n_clusters = 2 The average silhouette_score is : 0.7550327687037681
# For n_clusters = 3 The average silhouette_score is : 0.5866169079356702
# For n_clusters = 4 The average silhouette_score is : 0.4868628842176348
# For n_clusters = 5 The average silhouette_score is : 0.48120660208026766
# For n_clusters = 6 The average silhouette_score is : 0.44579208689073346
# For n_clusters = 7 The average silhouette_score is : 0.44221784603836767
# For n_clusters = 8 The average silhouette_score is : 0.463555852549505
# ----------------
# Project:  InterCafe-1
# For n_clusters = 2 The average silhouette_score is : 0.899080282869412
# For n_clusters = 3 The average silhouette_score is : 0.593354916830978
# For n_clusters = 4 The average silhouette_score is : 0.5423363239083788
# For n_clusters = 5 The average silhouette_score is : 0.5165477878479996
# For n_clusters = 6 The average silhouette_score is : 0.46324363723153705
# For n_clusters = 7 The average silhouette_score is : 0.43055290197341195
# For n_clusters = 8 The average silhouette_score is : 0.40575458997507985
# ----------------
# Project:  ivy-1.1
# For n_clusters = 2 The average silhouette_score is : 0.9082012646603318
# For n_clusters = 3 The average silhouette_score is : 0.8292985239942121
# For n_clusters = 4 The average silhouette_score is : 0.6687230911505476
# For n_clusters = 5 The average silhouette_score is : 0.6648685107607382
# For n_clusters = 6 The average silhouette_score is : 0.5070009828633453
# For n_clusters = 7 The average silhouette_score is : 0.5250455000266319
# For n_clusters = 8 The average silhouette_score is : 0.5287312916416844
# ----------------
# Project:  ivy-1.4
# For n_clusters = 2 The average silhouette_score is : 0.9795311066290252
# For n_clusters = 3 The average silhouette_score is : 0.9005102878823191
# For n_clusters = 4 The average silhouette_score is : 0.7595430045542655
# For n_clusters = 5 The average silhouette_score is : 0.7452427093239987
# For n_clusters = 6 The average silhouette_score is : 0.6872933818867464
# For n_clusters = 7 The average silhouette_score is : 0.6808524109486317
# For n_clusters = 8 The average silhouette_score is : 0.5806259479782725
# ----------------
# Project:  ivy-2
# For n_clusters = 2 The average silhouette_score is : 0.9609429183796648
# For n_clusters = 3 The average silhouette_score is : 0.8603917466423002
# For n_clusters = 4 The average silhouette_score is : 0.7482026748197179
# For n_clusters = 5 The average silhouette_score is : 0.7489199783511264
# For n_clusters = 6 The average silhouette_score is : 0.6987552200975563
# For n_clusters = 7 The average silhouette_score is : 0.5654014232683864
# For n_clusters = 8 The average silhouette_score is : 0.5682778324545246
# ----------------
# Project:  jEdit-3.2.1
# For n_clusters = 2 The average silhouette_score is : 0.9408535440086996
# For n_clusters = 3 The average silhouette_score is : 0.937498737836263
# For n_clusters = 4 The average silhouette_score is : 0.7966102704159319
# For n_clusters = 5 The average silhouette_score is : 0.7970547860587514
# For n_clusters = 6 The average silhouette_score is : 0.7869562424994251
# For n_clusters = 7 The average silhouette_score is : 0.7686141735386182
# For n_clusters = 8 The average silhouette_score is : 0.6663035062435665
# ----------------
# Project:  jEdit-4
# For n_clusters = 2 The average silhouette_score is : 0.9495906608072675
# For n_clusters = 3 The average silhouette_score is : 0.9458382675448055
# For n_clusters = 4 The average silhouette_score is : 0.9338197711266456
# For n_clusters = 5 The average silhouette_score is : 0.8025710976809236
# For n_clusters = 6 The average silhouette_score is : 0.7841281378492003
# For n_clusters = 7 The average silhouette_score is : 0.7938957351195771
# For n_clusters = 8 The average silhouette_score is : 0.6792970941276393
# ----------------
# Project:  jEdit-4.1
# For n_clusters = 2 The average silhouette_score is : 0.948239367094887
# For n_clusters = 3 The average silhouette_score is : 0.9433295160414875
# For n_clusters = 4 The average silhouette_score is : 0.7932449748883673
# For n_clusters = 5 The average silhouette_score is : 0.7928057097135299
# For n_clusters = 6 The average silhouette_score is : 0.783170616022945
# For n_clusters = 7 The average silhouette_score is : 0.6865280079672066
# For n_clusters = 8 The average silhouette_score is : 0.6872659808636201
# ----------------
# Project:  jEdit-4.2
# For n_clusters = 2 The average silhouette_score is : 0.9683026545604555
# For n_clusters = 3 The average silhouette_score is : 0.9487094773772976
# For n_clusters = 4 The average silhouette_score is : 0.824282948310961
# For n_clusters = 5 The average silhouette_score is : 0.8263484496067064
# For n_clusters = 6 The average silhouette_score is : 0.8004037796928993
# For n_clusters = 7 The average silhouette_score is : 0.7991454894249139
# For n_clusters = 8 The average silhouette_score is : 0.6146290763423199
# ----------------
# Project:  jEdit-4.3
# For n_clusters = 2 The average silhouette_score is : 0.9774799758822278
# For n_clusters = 3 The average silhouette_score is : 0.9474067188335527
# For n_clusters = 4 The average silhouette_score is : 0.9004406766236359
# For n_clusters = 5 The average silhouette_score is : 0.8243306299614827
# For n_clusters = 6 The average silhouette_score is : 0.7131939719568362
# For n_clusters = 7 The average silhouette_score is : 0.7695705532529868
# For n_clusters = 8 The average silhouette_score is : 0.6274237416097086
# ----------------
# Project:  KalkulatorDiety-1
# For n_clusters = 2 The average silhouette_score is : 0.8822685716257476
# For n_clusters = 3 The average silhouette_score is : 0.8662383971318103
# For n_clusters = 4 The average silhouette_score is : 0.609225955940562
# For n_clusters = 5 The average silhouette_score is : 0.5788188398869204
# For n_clusters = 6 The average silhouette_score is : 0.5380666657923219
# For n_clusters = 7 The average silhouette_score is : 0.5300411841346234
# For n_clusters = 8 The average silhouette_score is : 0.5354510400541708
# ----------------
# Project:  log4j-1
# For n_clusters = 2 The average silhouette_score is : 0.7235542085907418
# For n_clusters = 3 The average silhouette_score is : 0.6213122194440696
# For n_clusters = 4 The average silhouette_score is : 0.5551309368084314
# For n_clusters = 5 The average silhouette_score is : 0.5259495699687856
# For n_clusters = 6 The average silhouette_score is : 0.526376324967529
# For n_clusters = 7 The average silhouette_score is : 0.5251414218866728
# For n_clusters = 8 The average silhouette_score is : 0.47709067843720393
# ----------------
# Project:  log4j-1.1
# For n_clusters = 2 The average silhouette_score is : 0.6812600254349465
# For n_clusters = 3 The average silhouette_score is : 0.5767435643679308
# For n_clusters = 4 The average silhouette_score is : 0.5683705092794389
# For n_clusters = 5 The average silhouette_score is : 0.5364598086217375
# For n_clusters = 6 The average silhouette_score is : 0.5441869550179959
# For n_clusters = 7 The average silhouette_score is : 0.5554048721810231
# For n_clusters = 8 The average silhouette_score is : 0.48899585844667226
# ----------------
# Project:  log4j-1.2
# For n_clusters = 2 The average silhouette_score is : 0.9553294507011969
# For n_clusters = 3 The average silhouette_score is : 0.6750602326476273
# For n_clusters = 4 The average silhouette_score is : 0.5673741062036725
# For n_clusters = 5 The average silhouette_score is : 0.5182994284494233
# For n_clusters = 6 The average silhouette_score is : 0.510655813252863
# For n_clusters = 7 The average silhouette_score is : 0.5129425113718761
# For n_clusters = 8 The average silhouette_score is : 0.5003913971988304
# ----------------
# Project:  lucene-2
# For n_clusters = 2 The average silhouette_score is : 0.9007991217530418
# For n_clusters = 3 The average silhouette_score is : 0.6907052236954929
# For n_clusters = 4 The average silhouette_score is : 0.6089164522270023
# For n_clusters = 5 The average silhouette_score is : 0.59612231491282
# For n_clusters = 6 The average silhouette_score is : 0.5519716814433252
# For n_clusters = 7 The average silhouette_score is : 0.5935510114167437
# For n_clusters = 8 The average silhouette_score is : 0.5576865686733675
# ----------------
# Project:  lucene-2.2
# For n_clusters = 2 The average silhouette_score is : 0.9090554098236242
# For n_clusters = 3 The average silhouette_score is : 0.6810169174413815
# For n_clusters = 4 The average silhouette_score is : 0.6272120319575175
# For n_clusters = 5 The average silhouette_score is : 0.628984135625435
# For n_clusters = 6 The average silhouette_score is : 0.6291554084679121
# For n_clusters = 7 The average silhouette_score is : 0.5497750578888108
# For n_clusters = 8 The average silhouette_score is : 0.4876777965873285
# ----------------
# Project:  lucene-2.4
# For n_clusters = 2 The average silhouette_score is : 0.9570973441225061
# For n_clusters = 3 The average silhouette_score is : 0.8510333512468912
# For n_clusters = 4 The average silhouette_score is : 0.7101059111785664
# For n_clusters = 5 The average silhouette_score is : 0.7129537995994121
# For n_clusters = 6 The average silhouette_score is : 0.6542374924166959
# For n_clusters = 7 The average silhouette_score is : 0.6554320280981446
# For n_clusters = 8 The average silhouette_score is : 0.6287053322217923
# ----------------
# Project:  Nieruchomosci-1
# For n_clusters = 2 The average silhouette_score is : 0.6551761577031383
# For n_clusters = 3 The average silhouette_score is : 0.5356141847649843
# For n_clusters = 4 The average silhouette_score is : 0.5706875057499992
# For n_clusters = 5 The average silhouette_score is : 0.5323212415562755
# For n_clusters = 6 The average silhouette_score is : 0.545768194390334
# For n_clusters = 7 The average silhouette_score is : 0.5166884875306176
# For n_clusters = 8 The average silhouette_score is : 0.46864066232424273
# ----------------
# Project:  PdfTranslator-1
# For n_clusters = 2 The average silhouette_score is : 0.860917937873237
# For n_clusters = 3 The average silhouette_score is : 0.674366950975906
# For n_clusters = 4 The average silhouette_score is : 0.6286212122399344
# For n_clusters = 5 The average silhouette_score is : 0.6051876109611586
# For n_clusters = 6 The average silhouette_score is : 0.5306581982301378
# For n_clusters = 7 The average silhouette_score is : 0.4854514407161144
# For n_clusters = 8 The average silhouette_score is : 0.47421977674210325
# ----------------
# Project:  prop-1-4
# For n_clusters = 2 The average silhouette_score is : 0.8799244586745395
# For n_clusters = 3 The average silhouette_score is : 0.7378369433274595
# For n_clusters = 4 The average silhouette_score is : 0.7426594200583995
# For n_clusters = 5 The average silhouette_score is : 0.7075466280526171
# For n_clusters = 6 The average silhouette_score is : 0.6310557988428072
# For n_clusters = 7 The average silhouette_score is : 0.6327614561592158
# For n_clusters = 8 The average silhouette_score is : 0.631390807814956
# ----------------
# Project:  prop-2-9
# For n_clusters = 2 The average silhouette_score is : 0.9921270997921056
# For n_clusters = 3 The average silhouette_score is : 0.9886424096453632
# For n_clusters = 4 The average silhouette_score is : 0.9276958184715306
# For n_clusters = 5 The average silhouette_score is : 0.9128622469229273
# For n_clusters = 6 The average silhouette_score is : 0.8816021949340126
# For n_clusters = 7 The average silhouette_score is : 0.8287794989083287
# For n_clusters = 8 The average silhouette_score is : 0.7545259002017437
# ----------------
# Project:  prop-3-225
# For n_clusters = 2 The average silhouette_score is : 0.8901434391495859
# For n_clusters = 3 The average silhouette_score is : 0.8846190823560544
# For n_clusters = 4 The average silhouette_score is : 0.8091234503995868
# For n_clusters = 5 The average silhouette_score is : 0.6954258434366556
# For n_clusters = 6 The average silhouette_score is : 0.696789778868208
# For n_clusters = 7 The average silhouette_score is : 0.5719236162376258
# For n_clusters = 8 The average silhouette_score is : 0.570918006006202
# ----------------
# Project:  prop-4-285
# For n_clusters = 2 The average silhouette_score is : 0.9031394029078863
# For n_clusters = 3 The average silhouette_score is : 0.7963219448489527
# For n_clusters = 4 The average silhouette_score is : 0.7972609857707987
# For n_clusters = 5 The average silhouette_score is : 0.7507204052491131
# For n_clusters = 6 The average silhouette_score is : 0.7522875853600428
# For n_clusters = 7 The average silhouette_score is : 0.7074065297595086
# For n_clusters = 8 The average silhouette_score is : 0.6203669335073102
# ----------------
# Project:  prop-5-347
# For n_clusters = 2 The average silhouette_score is : 0.9851391965961009
# For n_clusters = 3 The average silhouette_score is : 0.8815846258368304
# For n_clusters = 4 The average silhouette_score is : 0.7760979133055933
# For n_clusters = 5 The average silhouette_score is : 0.6671311194858407
# For n_clusters = 6 The average silhouette_score is : 0.5686306879678592
# For n_clusters = 7 The average silhouette_score is : 0.5765704447683808
# For n_clusters = 8 The average silhouette_score is : 0.5357941915575216
# ----------------
# Project:  prop-6-452
# For n_clusters = 2 The average silhouette_score is : 0.6381631872642034
# For n_clusters = 3 The average silhouette_score is : 0.5512552169490273
# For n_clusters = 4 The average silhouette_score is : 0.4726479717311785
# For n_clusters = 5 The average silhouette_score is : 0.5046174247746951
# For n_clusters = 6 The average silhouette_score is : 0.5123139487322415
# For n_clusters = 7 The average silhouette_score is : 0.45172518356318325
# For n_clusters = 8 The average silhouette_score is : 0.4593170946973077
# ----------------
# Project:  Redaktor-1
# For n_clusters = 2 The average silhouette_score is : 0.697098588171352
# For n_clusters = 3 The average silhouette_score is : 0.6054643684823602
# For n_clusters = 4 The average silhouette_score is : 0.5608599884180573
# For n_clusters = 5 The average silhouette_score is : 0.5280124630974968
# For n_clusters = 6 The average silhouette_score is : 0.5355031649703246
# For n_clusters = 7 The average silhouette_score is : 0.5333997064062822
# For n_clusters = 8 The average silhouette_score is : 0.4926556926653356
# ----------------
# Project:  Serapion-1
# For n_clusters = 2 The average silhouette_score is : 0.8783444329880615
# For n_clusters = 3 The average silhouette_score is : 0.6946256774535763
# For n_clusters = 4 The average silhouette_score is : 0.6785301924427455
# For n_clusters = 5 The average silhouette_score is : 0.6028870929347153
# For n_clusters = 6 The average silhouette_score is : 0.458058457204317
# For n_clusters = 7 The average silhouette_score is : 0.47170932774324165
# For n_clusters = 8 The average silhouette_score is : 0.4714103244877279
# ----------------
# Project:  Skarbonka-1
# For n_clusters = 2 The average silhouette_score is : 0.6940598726747019
# For n_clusters = 3 The average silhouette_score is : 0.6188666371835564
# For n_clusters = 4 The average silhouette_score is : 0.5749696122468857
# For n_clusters = 5 The average silhouette_score is : 0.5801994564878596
# For n_clusters = 6 The average silhouette_score is : 0.5676685046628344
# For n_clusters = 7 The average silhouette_score is : 0.5655335926986998
# For n_clusters = 8 The average silhouette_score is : 0.5380089814944568
# ----------------
# Project:  SklepAGD-1
# For n_clusters = 2 The average silhouette_score is : 0.7171952856872452
# For n_clusters = 3 The average silhouette_score is : 0.7027587684740237
# For n_clusters = 4 The average silhouette_score is : 0.5370171307275277
# For n_clusters = 5 The average silhouette_score is : 0.5031698070953301
# For n_clusters = 6 The average silhouette_score is : 0.4936232911709693
# For n_clusters = 7 The average silhouette_score is : 0.4998123920447042
# For n_clusters = 8 The average silhouette_score is : 0.40710958134304337
# ----------------
# Project:  synapse-1
# For n_clusters = 2 The average silhouette_score is : 0.6803243332955587
# For n_clusters = 3 The average silhouette_score is : 0.66354948285032
# For n_clusters = 4 The average silhouette_score is : 0.5161865634779358
# For n_clusters = 5 The average silhouette_score is : 0.517091302718605
# For n_clusters = 6 The average silhouette_score is : 0.5182685564812703
# For n_clusters = 7 The average silhouette_score is : 0.534132422060404
# For n_clusters = 8 The average silhouette_score is : 0.461340330664217
# ----------------
# Project:  synapse-1.1
# For n_clusters = 2 The average silhouette_score is : 0.6579413472367711
# For n_clusters = 3 The average silhouette_score is : 0.6373593029558586
# For n_clusters = 4 The average silhouette_score is : 0.5098165119242601
# For n_clusters = 5 The average silhouette_score is : 0.5126775521668065
# For n_clusters = 6 The average silhouette_score is : 0.5157682819279916
# For n_clusters = 7 The average silhouette_score is : 0.5147034363388485
# For n_clusters = 8 The average silhouette_score is : 0.5290995259351752
# ----------------
# Project:  synapse-1.2
# For n_clusters = 2 The average silhouette_score is : 0.6814170476037656
# For n_clusters = 3 The average silhouette_score is : 0.6731104628595428
# For n_clusters = 4 The average silhouette_score is : 0.6750121650543863
# For n_clusters = 5 The average silhouette_score is : 0.6422111191358568
# For n_clusters = 6 The average silhouette_score is : 0.5264021458170861
# For n_clusters = 7 The average silhouette_score is : 0.5146594934741036
# For n_clusters = 8 The average silhouette_score is : 0.5145211553168936
# ----------------
# Project:  SystemDataManagement-1
# For n_clusters = 2 The average silhouette_score is : 0.8716411628144233
# For n_clusters = 3 The average silhouette_score is : 0.7483922628291706
# For n_clusters = 4 The average silhouette_score is : 0.6966283605879796
# For n_clusters = 5 The average silhouette_score is : 0.5897650442176964
# For n_clusters = 6 The average silhouette_score is : 0.5723105600972245
# For n_clusters = 7 The average silhouette_score is : 0.6049673173507412
# For n_clusters = 8 The average silhouette_score is : 0.5981025781662247
# ----------------
# Project:  SzybkaFucha-1
# For n_clusters = 2 The average silhouette_score is : 0.5283206401685808
# For n_clusters = 3 The average silhouette_score is : 0.5869678381478343
# For n_clusters = 4 The average silhouette_score is : 0.5393709708704002
# For n_clusters = 5 The average silhouette_score is : 0.49536473263990854
# For n_clusters = 6 The average silhouette_score is : 0.45515608397105056
# For n_clusters = 7 The average silhouette_score is : 0.43384543234517275
# For n_clusters = 8 The average silhouette_score is : 0.3620454186402284
# ----------------
# Project:  TermoProjekt-1
# For n_clusters = 2 The average silhouette_score is : 0.8909617025819999
# For n_clusters = 3 The average silhouette_score is : 0.7456703070285516
# For n_clusters = 4 The average silhouette_score is : 0.627729445222152
# For n_clusters = 5 The average silhouette_score is : 0.6048104215386405
# For n_clusters = 6 The average silhouette_score is : 0.5211611083603018
# For n_clusters = 7 The average silhouette_score is : 0.5160651119832524
# For n_clusters = 8 The average silhouette_score is : 0.4765761776714766
# ----------------
# Project:  Tomcat-6.0.389418
# For n_clusters = 2 The average silhouette_score is : 0.9773849734192628
# For n_clusters = 3 The average silhouette_score is : 0.8286821303770556
# For n_clusters = 4 The average silhouette_score is : 0.7878252575318352
# For n_clusters = 5 The average silhouette_score is : 0.7010646845828099
# For n_clusters = 6 The average silhouette_score is : 0.7062103804875765
# For n_clusters = 7 The average silhouette_score is : 0.6813602537618438
# For n_clusters = 8 The average silhouette_score is : 0.5994287400488226
# ----------------
# Project:  velocity-1.5
# For n_clusters = 2 The average silhouette_score is : 0.9734894052848633
# For n_clusters = 3 The average silhouette_score is : 0.9699633105885672
# For n_clusters = 4 The average silhouette_score is : 0.6738407056962028
# For n_clusters = 5 The average silhouette_score is : 0.6888872519500565
# For n_clusters = 6 The average silhouette_score is : 0.58046269517304
# For n_clusters = 7 The average silhouette_score is : 0.5673635435298706
# For n_clusters = 8 The average silhouette_score is : 0.5597392401382396
# ----------------
# Project:  velocity-1.6.1
# For n_clusters = 2 The average silhouette_score is : 0.9734890018513158
# For n_clusters = 3 The average silhouette_score is : 0.9697890680407629
# For n_clusters = 4 The average silhouette_score is : 0.6329915665566995
# For n_clusters = 5 The average silhouette_score is : 0.6432601588915695
# For n_clusters = 6 The average silhouette_score is : 0.6504907514702261
# For n_clusters = 7 The average silhouette_score is : 0.6302203399900937
# For n_clusters = 8 The average silhouette_score is : 0.5357672752763605
# ----------------
# Project:  WorkFlow-1
# For n_clusters = 2 The average silhouette_score is : 0.9282493386750128
# For n_clusters = 3 The average silhouette_score is : 0.8636552478473815
# For n_clusters = 4 The average silhouette_score is : 0.5317802827883044
# For n_clusters = 5 The average silhouette_score is : 0.5707451044061085
# For n_clusters = 6 The average silhouette_score is : 0.5726363507127455
# For n_clusters = 7 The average silhouette_score is : 0.5790915852464779
# For n_clusters = 8 The average silhouette_score is : 0.4190119331103753
# ----------------
# Project:  WspomaganiePI-1
# For n_clusters = 2 The average silhouette_score is : 0.6467577814517789
# For n_clusters = 3 The average silhouette_score is : 0.5533897545114417
# For n_clusters = 4 The average silhouette_score is : 0.5767853916737538
# For n_clusters = 5 The average silhouette_score is : 0.5969461322971931
# For n_clusters = 6 The average silhouette_score is : 0.5769607830113779
# For n_clusters = 7 The average silhouette_score is : 0.5137775590942226
# For n_clusters = 8 The average silhouette_score is : 0.4455939446197582
# ----------------
# Project:  xerces-1.2.0
# For n_clusters = 2 The average silhouette_score is : 0.9237207408962052
# For n_clusters = 3 The average silhouette_score is : 0.8281109370419816
# For n_clusters = 4 The average silhouette_score is : 0.7732169525856664
# For n_clusters = 5 The average silhouette_score is : 0.7683868086435338
# For n_clusters = 6 The average silhouette_score is : 0.7626415811902484
# For n_clusters = 7 The average silhouette_score is : 0.6670679323936995
# For n_clusters = 8 The average silhouette_score is : 0.6583105360744579
# ----------------
# Project:  xerces-1.3.0
# For n_clusters = 2 The average silhouette_score is : 0.9268506325885064
# For n_clusters = 3 The average silhouette_score is : 0.8323022399359126
# For n_clusters = 4 The average silhouette_score is : 0.7645841423973337
# For n_clusters = 5 The average silhouette_score is : 0.7632667936651414
# For n_clusters = 6 The average silhouette_score is : 0.7064723925535349
# For n_clusters = 7 The average silhouette_score is : 0.7044993721928894
# For n_clusters = 8 The average silhouette_score is : 0.6935021455057567
# ----------------
# Project:  xerces-1.4.4
# For n_clusters = 2 The average silhouette_score is : 0.8777885471602243
# For n_clusters = 3 The average silhouette_score is : 0.8008980172442646
# For n_clusters = 4 The average silhouette_score is : 0.7821745638304227
# For n_clusters = 5 The average silhouette_score is : 0.7506324619835154
# For n_clusters = 6 The average silhouette_score is : 0.7184579026276301
# For n_clusters = 7 The average silhouette_score is : 0.6329145693207687
# For n_clusters = 8 The average silhouette_score is : 0.6537703680632104
# ----------------
# Project:  xerces-init
# For n_clusters = 2 The average silhouette_score is : 0.8911031538632571
# For n_clusters = 3 The average silhouette_score is : 0.8244441398896759
# For n_clusters = 4 The average silhouette_score is : 0.8338140741256577
# For n_clusters = 5 The average silhouette_score is : 0.8308863947681489
# For n_clusters = 6 The average silhouette_score is : 0.7403606696447533
# For n_clusters = 7 The average silhouette_score is : 0.7461332948575619
# For n_clusters = 8 The average silhouette_score is : 0.7387274303648517
# ----------------
# Project:  Zuzel-1
# For n_clusters = 2 The average silhouette_score is : 0.7149193572793978
# For n_clusters = 3 The average silhouette_score is : 0.7075686179448131
# For n_clusters = 4 The average silhouette_score is : 0.6284251326824716
# For n_clusters = 5 The average silhouette_score is : 0.5988237884414365
# For n_clusters = 6 The average silhouette_score is : 0.5829769619001135
# For n_clusters = 7 The average silhouette_score is : 0.5601978139321239
# For n_clusters = 8 The average silhouette_score is : 0.48477054605892034
# ----------------

# %% [markdown]
# ### Comparison

# %% [markdown]
# The average silhouette scores for all values of k is converted into a dataframe project wise.

# %%
def create_df(df_list,target_list):
    new_df = pd.DataFrame(columns=target_list, data=df_list)
    return new_df

# %%
column_list=["PROJECT-NAME","2-CLUSTERS","3-CLUSTERS","4-CLUSTERS","5-CLUSTERS","6-CLUSTERS","7-CLUSTERS","8-CLUSTERS"]
new_df=create_df(df_list,column_list)
new_df.head(10)
# Out:
#     PROJECT-NAME  2-CLUSTERS  3-CLUSTERS  4-CLUSTERS  5-CLUSTERS  6-CLUSTERS  \
# 0        ant-1.3      0.8677      0.6449      0.6260      0.5734      0.5652
# 1        ant-1.4      0.6910      0.6536      0.6517      0.6641      0.5987
# 2        ant-1.5      0.7951      0.7194      0.7119      0.6651      0.6602
# 3        ant-1.6      0.7497      0.7336      0.6732      0.6710      0.5980
# 4        ant-1.7      0.7941      0.7678      0.6999      0.5783      0.5785
# 5  ArcPlatform-1      0.8036      0.7668      0.7456      0.5646      0.5625
# 6        Berek-1      0.8901      0.6676      0.6426      0.6361      0.6175
# 7        camel-1      0.9023      0.7299      0.7051      0.5565      0.5627
# 8      camel-1.2      0.9538      0.8464      0.6387      0.6153      0.5597
# 9      camel-1.4      0.9756      0.8613      0.6504      0.6492      0.6462
#
#    7-CLUSTERS  8-CLUSTERS
# 0      0.5716      0.4618
# 1      0.5042      0.4949
# 2      0.5671      0.5768
# 3      0.6013      0.6003
# 4      0.5808      0.5813
# 5      0.5504      0.5351
# 6      0.6333      0.5991
# 7      0.5345      0.5351
# 8      0.5623      0.5012
# 9      0.6490      0.5817

# %% [markdown]
# The silhouette dataframe shows that the n_cluster value of 3 is a good pick.

# %% [markdown]
# ### Information gain

# %%
from __future__ import division
from docopt import docopt
from collections import Counter
from docopt import docopt
import pandas
import math

# %%
def entropy(l):
    p = Counter(l)
    total = float(len(l))
    return -sum(count/total * math.log(count/total, 2) for count in p.values())

# %%
dfList=[]
for files in read_files:
    data=pd.read_csv(files)
    class_entropy = round(entropy(data['bug'].tolist()),4)
    print('Class entropy:', class_entropy)
    
    decision_entropy = 0
    target=data.iloc[0,0]+"-"+str(data.iloc[0,1])
    r_list=[]
    r_list.append(target)
    r_list.append(class_entropy)
    col=list(data.columns[3:21].values)
    for i in col:
        
        for name, g in data.groupby(i):
            g_total = g.count().values[0]
            p = Counter(g['bug'].tolist())
            r = []
            for v in p.values():
                r.append(-v/g_total * math.log(v/g_total, 2))
            decision_entropy += g_total/data.count().values[0] * sum(r)
        #print('Column age:', decision_entropy)
        gain=round(abs(class_entropy - decision_entropy),4)
        print('Gain of :'+i+ str(gain ))
        r_list.append(gain)
    dfList.append(r_list)
    print(r_list)
    print("-----")
# Out:
# Class entropy: 0.8645
# Gain of :wmc0.4248
# Gain of :dit0.3744
# Gain of :noc1.1848
# Gain of :cbo1.6589
# Gain of :rfc1.8447
# Gain of :lcom2.1333
# Gain of :ca2.6906
# Gain of :ce3.2264
# Gain of :npm3.6839
# Gain of :lcom33.7471
# Gain of :loc3.7791
# Gain of :dam4.4177
# Gain of :moa5.1634
# Gain of :mfa5.6333
# Gain of :cam5.7188
# Gain of :ic6.5095
# Gain of :cbm7.2728
# Gain of :amc7.2888
# ['ant-1.3', 0.8645, 0.4248, 0.3744, 1.1848, 1.6589, 1.8447, 2.1333, 2.6906, 3.2264, 3.6839, 3.7471, 3.7791, 4.4177, 5.1634, 5.6333, 5.7188, 6.5095, 7.2728, 7.2888]
# -----
# Class entropy: 0.9181
# Gain of :wmc0.2178
# Gain of :dit0.629
# Gain of :noc1.4844
# Gain of :cbo2.0975
# Gain of :rfc2.528
# Gain of :lcom3.0553
# Gain of :ca3.8332
# Gain of :ce4.4812
# Gain of :npm5.1743
# Gain of :lcom35.558
# Gain of :loc5.6949
# Gain of :dam6.4864
# Gain of :moa7.2834
# Gain of :mfa7.6674
# Gain of :cam7.9923
# Gain of :ic8.8549
# Gain of :cbm9.6956
# Gain of :amc9.7925
# ['ant-1.4', 0.9181, 0.2178, 0.629, 1.4844, 2.0975, 2.528, 3.0553, 3.8332, 4.4812, 5.1743, 5.558, 5.6949, 6.4864, 7.2834, 7.6674, 7.9923, 8.8549, 9.6956, 9.7925]
# -----
# Class entropy: 0.5466
# Gain of :wmc0.2266
# Gain of :dit0.2907
# Gain of :noc0.8052
# Gain of :cbo1.1776
# Gain of :rfc1.3283
# Gain of :lcom1.4814
# Gain of :ca1.9566
# Gain of :ce2.288
# Gain of :npm2.6541
# Gain of :lcom32.78
# Gain of :loc2.8414
# Gain of :dam3.2051
# Gain of :moa3.6751
# Gain of :mfa3.8639
# Gain of :cam3.9936
# Gain of :ic4.4866
# Gain of :cbm4.9477
# Gain of :amc4.9477
# ['ant-1.5', 0.5466, 0.2266, 0.2907, 0.8052, 1.1776, 1.3283, 1.4814, 1.9566, 2.288, 2.6541, 2.78, 2.8414, 3.2051, 3.6751, 3.8639, 3.9936, 4.4866, 4.9477, 4.9477]
# -----
# Class entropy: 1.327
# Gain of :wmc0.5754
# Gain of :dit0.6684
# Gain of :noc1.9254
# Gain of :cbo2.7281
# Gain of :rfc3.1831
# Gain of :lcom3.678
# Gain of :ca4.7069
# Gain of :ce5.5978
# Gain of :npm6.4245
# Gain of :lcom36.7012
# Gain of :loc6.798
# Gain of :dam7.7778
# Gain of :moa8.8935
# Gain of :mfa9.536
# Gain of :cam9.8482
# Gain of :ic11.1112
# Gain of :cbm12.3082
# Gain of :amc12.3911
# ['ant-1.6', 1.327, 0.5754, 0.6684, 1.9254, 2.7281, 3.1831, 3.678, 4.7069, 5.5978, 6.4245, 6.7012, 6.798, 7.7778, 8.8935, 9.536, 9.8482, 11.1112, 12.3082, 12.3911]
# -----
# Class entropy: 1.206
# Gain of :wmc0.4436
# Gain of :dit0.71
# Gain of :noc1.8577
# Gain of :cbo2.7091
# Gain of :rfc3.23
# Gain of :lcom3.6917
# Gain of :ca4.709
# Gain of :ce5.5722
# Gain of :npm6.434
# Gain of :lcom36.7505
# Gain of :loc6.9255
# Gain of :dam7.8231
# Gain of :moa8.8682
# Gain of :mfa9.4621
# Gain of :cam9.7981
# Gain of :ic10.9611
# Gain of :cbm12.0857
# Gain of :amc12.1802
# ['ant-1.7', 1.206, 0.4436, 0.71, 1.8577, 2.7091, 3.23, 3.6917, 4.709, 5.5722, 6.434, 6.7505, 6.9255, 7.8231, 8.8682, 9.4621, 9.7981, 10.9611, 12.0857, 12.1802]
# -----
# Class entropy: 0.6041
# Gain of :wmc0.2347
# Gain of :dit0.3424
# Gain of :noc0.9419
# Gain of :cbo1.2654
# Gain of :rfc1.5223
# Gain of :lcom1.7594
# Gain of :ca2.2936
# Gain of :ce2.6621
# Gain of :npm3.0546
# Gain of :lcom33.3949
# Gain of :loc3.531
# Gain of :dam4.126
# Gain of :moa4.6576
# Gain of :mfa5.1741
# Gain of :cam5.3336
# Gain of :ic5.9261
# Gain of :cbm6.5174
# Gain of :amc6.6852
# ['ArcPlatform-1', 0.6041, 0.2347, 0.3424, 0.9419, 1.2654, 1.5223, 1.7594, 2.2936, 2.6621, 3.0546, 3.3949, 3.531, 4.126, 4.6576, 5.1741, 5.3336, 5.9261, 6.5174, 6.6852]
# -----
# Class entropy: 1.836
# Gain of :wmc1.528
# Gain of :dit0.2501
# Gain of :noc1.57
# Gain of :cbo1.9597
# Gain of :rfc1.9597
# Gain of :lcom2.1932
# Gain of :ca2.5989
# Gain of :ce3.1399
# Gain of :npm3.846
# Gain of :lcom33.9566
# Gain of :loc3.9566
# Gain of :dam4.6496
# Gain of :moa5.7428
# Gain of :mfa6.567
# Gain of :cam6.7416
# Gain of :ic8.4125
# Gain of :cbm10.0834
# Gain of :amc10.0834
# ['Berek-1', 1.836, 1.528, 0.2501, 1.57, 1.9597, 1.9597, 2.1932, 2.5989, 3.1399, 3.846, 3.9566, 3.9566, 4.6496, 5.7428, 6.567, 6.7416, 8.4125, 10.0834, 10.0834]
# -----
# Class entropy: 0.2497
# Gain of :wmc0.0915
# Gain of :dit0.1358
# Gain of :noc0.3447
# Gain of :cbo0.4727
# Gain of :rfc0.5752
# Gain of :lcom0.6571
# Gain of :ca0.8197
# Gain of :ce0.9938
# Gain of :npm1.1432
# Gain of :lcom31.2793
# Gain of :loc1.3181
# Gain of :dam1.5626
# Gain of :moa1.7906
# Gain of :mfa1.9682
# Gain of :cam2.0456
# Gain of :ic2.29
# Gain of :cbm2.5331
# Gain of :amc2.6027
# ['camel-1', 0.2497, 0.0915, 0.1358, 0.3447, 0.4727, 0.5752, 0.6571, 0.8197, 0.9938, 1.1432, 1.2793, 1.3181, 1.5626, 1.7906, 1.9682, 2.0456, 2.29, 2.5331, 2.6027]
# -----
# Class entropy: 1.7451
# Gain of :wmc0.4238
# Gain of :dit1.2327
# Gain of :noc2.8763
# Gain of :cbo4.2426
# Gain of :rfc5.4042
# Gain of :lcom6.4089
# Gain of :ca7.8799
# Gain of :ce9.3199
# Gain of :npm10.6902
# Gain of :lcom311.7383
# Gain of :loc12.4359
# Gain of :dam14.039
# Gain of :moa15.6545
# Gain of :mfa16.7802
# Gain of :cam17.6409
# Gain of :ic19.3486
# Gain of :cbm20.9836
# Gain of :amc21.5282
# ['camel-1.2', 1.7451, 0.4238, 1.2327, 2.8763, 4.2426, 5.4042, 6.4089, 7.8799, 9.3199, 10.6902, 11.7383, 12.4359, 14.039, 15.6545, 16.7802, 17.6409, 19.3486, 20.9836, 21.5282]
# -----
# Class entropy: 1.0121
# Gain of :wmc0.3
# Gain of :dit0.6373
# Gain of :noc1.5768
# Gain of :cbo2.3397
# Gain of :rfc2.961
# Gain of :lcom3.4668
# Gain of :ca4.2658
# Gain of :ce5.0702
# Gain of :npm5.8068
# Gain of :lcom36.3742
# Gain of :loc6.729
# Gain of :dam7.6701
# Gain of :moa8.59
# Gain of :mfa9.1646
# Gain of :cam9.5694
# Gain of :ic10.5527
# Gain of :cbm11.5033
# Gain of :amc11.8138
# ['camel-1.4', 1.0121, 0.3, 0.6373, 1.5768, 2.3397, 2.961, 3.4668, 4.2658, 5.0702, 5.8068, 6.3742, 6.729, 7.6701, 8.59, 9.1646, 9.5694, 10.5527, 11.5033, 11.8138]
# -----
# Class entropy: 1.159
# Gain of :wmc0.2936
# Gain of :dit0.8082
# Gain of :noc1.8717
# Gain of :cbo2.7313
# Gain of :rfc3.4711
# Gain of :lcom4.1427
# Gain of :ca5.0525
# Gain of :ce5.986
# Gain of :npm6.865
# Gain of :lcom37.5288
# Gain of :loc7.9854
# Gain of :dam9.0605
# Gain of :moa10.135
# Gain of :mfa10.8812
# Gain of :cam11.4379
# Gain of :ic12.5628
# Gain of :cbm13.6642
# Gain of :amc14.0333
# ['camel-1.6', 1.159, 0.2936, 0.8082, 1.8717, 2.7313, 3.4711, 4.1427, 5.0525, 5.986, 6.865, 7.5288, 7.9854, 9.0605, 10.135, 10.8812, 11.4379, 12.5628, 13.6642, 14.0333]
# -----
# Class entropy: 0.5026
# Gain of :wmc0.4462
# Gain of :dit0.0135
# Gain of :noc0.4755
# Gain of :cbo0.719
# Gain of :rfc0.7815
# Gain of :lcom0.8558
# Gain of :ca1.26
# Gain of :ce1.5073
# Gain of :npm1.5637
# Gain of :lcom31.7023
# Gain of :loc1.7335
# Gain of :dam2.2032
# Gain of :moa2.514
# Gain of :mfa2.6023
# Gain of :cam2.6335
# Gain of :ic3.0697
# Gain of :cbm3.5058
# Gain of :amc3.5058
# ['E-Learning-1', 0.5026, 0.4462, 0.0135, 0.4755, 0.719, 0.7815, 0.8558, 1.26, 1.5073, 1.5637, 1.7023, 1.7335, 2.2032, 2.514, 2.6023, 2.6335, 3.0697, 3.5058, 3.5058]
# -----
# Class entropy: 0.8274
# Gain of :wmc0.7254
# Gain of :dit0.0661
# Gain of :noc0.7526
# Gain of :cbo0.897
# Gain of :rfc0.9711
# Gain of :lcom1.0731
# Gain of :ca1.0731
# Gain of :ce1.371
# Gain of :npm1.5471
# Gain of :lcom31.5471
# Gain of :loc1.5471
# Gain of :dam1.9567
# Gain of :moa2.4577
# Gain of :mfa2.8539
# Gain of :cam2.8539
# Gain of :ic3.5674
# Gain of :cbm4.281
# Gain of :amc4.281
# ['InterCafe-1', 0.8274, 0.7254, 0.0661, 0.7526, 0.897, 0.9711, 1.0731, 1.0731, 1.371, 1.5471, 1.5471, 1.5471, 1.9567, 2.4577, 2.8539, 2.8539, 3.5674, 4.281, 4.281]
# -----
# Class entropy: 2.4996
# Gain of :wmc1.2512
# Gain of :dit0.8971
# Gain of :noc3.1516
# Gain of :cbo4.4674
# Gain of :rfc5.0997
# Gain of :lcom5.9046
# Gain of :ca7.513
# Gain of :ce8.9311
# Gain of :npm10.4156
# Gain of :lcom311.1207
# Gain of :loc11.3009
# Gain of :dam13.429
# Gain of :moa15.6387
# Gain of :mfa17.2001
# Gain of :cam17.792
# Gain of :ic19.9942
# Gain of :cbm22.0999
# Gain of :amc22.3326
# ['ivy-1.1', 2.4996, 1.2512, 0.8971, 3.1516, 4.4674, 5.0997, 5.9046, 7.513, 8.9311, 10.4156, 11.1207, 11.3009, 13.429, 15.6387, 17.2001, 17.792, 19.9942, 22.0999, 22.3326]
# -----
# Class entropy: 0.3747
# Gain of :wmc0.1649
# Gain of :dit0.1944
# Gain of :noc0.5257
# Gain of :cbo0.7511
# Gain of :rfc0.8754
# Gain of :lcom1.0202
# Gain of :ca1.2618
# Gain of :ce1.5209
# Gain of :npm1.7745
# Gain of :lcom31.9258
# Gain of :loc1.9625
# Gain of :dam2.2821
# Gain of :moa2.615
# Gain of :mfa2.825
# Gain of :cam2.9196
# Gain of :ic3.2696
# Gain of :cbm3.6036
# Gain of :amc3.6467
# ['ivy-1.4', 0.3747, 0.1649, 0.1944, 0.5257, 0.7511, 0.8754, 1.0202, 1.2618, 1.5209, 1.7745, 1.9258, 1.9625, 2.2821, 2.615, 2.825, 2.9196, 3.2696, 3.6036, 3.6467]
# -----
# Class entropy: 0.6422
# Gain of :wmc0.3006
# Gain of :dit0.2972
# Gain of :noc0.9047
# Gain of :cbo1.252
# Gain of :rfc1.453
# Gain of :lcom1.6366
# Gain of :ca2.1385
# Gain of :ce2.5095
# Gain of :npm2.8695
# Gain of :lcom33.0098
# Gain of :loc3.064
# Gain of :dam3.5686
# Gain of :moa4.1008
# Gain of :mfa4.5245
# Gain of :cam4.6253
# Gain of :ic5.2526
# Gain of :cbm5.848
# Gain of :amc5.896
# ['ivy-2', 0.6422, 0.3006, 0.2972, 0.9047, 1.252, 1.453, 1.6366, 2.1385, 2.5095, 2.8695, 3.0098, 3.064, 3.5686, 4.1008, 4.5245, 4.6253, 5.2526, 5.848, 5.896]
# -----
# Class entropy: 1.8833
# Gain of :wmc0.8261
# Gain of :dit0.719
# Gain of :noc2.5292
# Gain of :cbo3.6731
# Gain of :rfc4.2329
# Gain of :lcom4.9671
# Gain of :ca6.2309
# Gain of :ce7.4342
# Gain of :npm8.6457
# Gain of :lcom39.1115
# Gain of :loc9.2365
# Gain of :dam10.5743
# Gain of :moa12.0596
# Gain of :mfa12.8197
# Gain of :cam13.3782
# Gain of :ic15.0385
# Gain of :cbm16.5218
# Gain of :amc16.6526
# ['jEdit-3.2.1', 1.8833, 0.8261, 0.719, 2.5292, 3.6731, 4.2329, 4.9671, 6.2309, 7.4342, 8.6457, 9.1115, 9.2365, 10.5743, 12.0596, 12.8197, 13.3782, 15.0385, 16.5218, 16.6526]
# -----
# Class entropy: 1.3843
# Gain of :wmc0.6391
# Gain of :dit0.512
# Gain of :noc1.8595
# Gain of :cbo2.6501
# Gain of :rfc3.0877
# Gain of :lcom3.5477
# Gain of :ca4.4259
# Gain of :ce5.3082
# Gain of :npm6.1046
# Gain of :lcom36.4139
# Gain of :loc6.5211
# Gain of :dam7.5085
# Gain of :moa8.5608
# Gain of :mfa9.2688
# Gain of :cam9.5872
# Gain of :ic10.8692
# Gain of :cbm12.0026
# Gain of :amc12.0587
# ['jEdit-4', 1.3843, 0.6391, 0.512, 1.8595, 2.6501, 3.0877, 3.5477, 4.4259, 5.3082, 6.1046, 6.4139, 6.5211, 7.5085, 8.5608, 9.2688, 9.5872, 10.8692, 12.0026, 12.0587]
# -----
# Class entropy: 1.4327
# Gain of :wmc0.7208
# Gain of :dit0.4988
# Gain of :noc1.8951
# Gain of :cbo2.7447
# Gain of :rfc3.2013
# Gain of :lcom3.7023
# Gain of :ca4.6173
# Gain of :ce5.4726
# Gain of :npm6.3529
# Gain of :lcom36.6957
# Gain of :loc6.8367
# Gain of :dam7.6252
# Gain of :moa8.7444
# Gain of :mfa9.3881
# Gain of :cam9.7092
# Gain of :ic10.9986
# Gain of :cbm12.157
# Gain of :amc12.1892
# ['jEdit-4.1', 1.4327, 0.7208, 0.4988, 1.8951, 2.7447, 3.2013, 3.7023, 4.6173, 5.4726, 6.3529, 6.6957, 6.8367, 7.6252, 8.7444, 9.3881, 9.7092, 10.9986, 12.157, 12.1892]
# -----
# Class entropy: 0.82
# Gain of :wmc0.4308
# Gain of :dit0.2976
# Gain of :noc1.0822
# Gain of :cbo1.4849
# Gain of :rfc1.6613
# Gain of :lcom1.8493
# Gain of :ca2.2773
# Gain of :ce2.7347
# Gain of :npm3.1625
# Gain of :lcom33.2873
# Gain of :loc3.3275
# Gain of :dam3.7883
# Gain of :moa4.4221
# Gain of :mfa4.869
# Gain of :cam4.9884
# Gain of :ic5.7476
# Gain of :cbm6.4117
# Gain of :amc6.4525
# ['jEdit-4.2', 0.82, 0.4308, 0.2976, 1.0822, 1.4849, 1.6613, 1.8493, 2.2773, 2.7347, 3.1625, 3.2873, 3.3275, 3.7883, 4.4221, 4.869, 4.9884, 5.7476, 6.4117, 6.4525]
# -----
# Class entropy: 0.1643
# Gain of :wmc0.0875
# Gain of :dit0.055
# Gain of :noc0.2163
# Gain of :cbo0.2915
# Gain of :rfc0.3316
# Gain of :lcom0.4031
# Gain of :ca0.4838
# Gain of :ce0.5563
# Gain of :npm0.6405
# Gain of :lcom30.6947
# Gain of :loc0.7292
# Gain of :dam0.8509
# Gain of :moa0.9698
# Gain of :mfa1.0566
# Gain of :cam1.0986
# Gain of :ic1.2506
# Gain of :cbm1.3857
# Gain of :amc1.4193
# ['jEdit-4.3', 0.1643, 0.0875, 0.055, 0.2163, 0.2915, 0.3316, 0.4031, 0.4838, 0.5563, 0.6405, 0.6947, 0.7292, 0.8509, 0.9698, 1.0566, 1.0986, 1.2506, 1.3857, 1.4193]
# -----
# Class entropy: 0.9087
# Gain of :wmc0.2829
# Gain of :dit0.2009
# Gain of :noc1.0815
# Gain of :cbo1.6332
# Gain of :rfc1.9113
# Gain of :lcom2.4215
# Gain of :ca2.959
# Gain of :ce3.4404
# Gain of :npm4.0904
# Gain of :lcom34.4653
# Gain of :loc4.5394
# Gain of :dam5.319
# Gain of :moa5.8577
# Gain of :mfa6.1638
# Gain of :cam6.5477
# Gain of :ic7.4283
# Gain of :cbm8.3089
# Gain of :amc8.383
# ['KalkulatorDiety-1', 0.9087, 0.2829, 0.2009, 1.0815, 1.6332, 1.9113, 2.4215, 2.959, 3.4404, 4.0904, 4.4653, 4.5394, 5.319, 5.8577, 6.1638, 6.5477, 7.4283, 8.3089, 8.383]
# -----
# Class entropy: 1.2074
# Gain of :wmc0.5424
# Gain of :dit0.5811
# Gain of :noc1.6713
# Gain of :cbo2.2563
# Gain of :rfc2.6681
# Gain of :lcom3.0965
# Gain of :ca3.785
# Gain of :ce4.5679
# Gain of :npm5.2544
# Gain of :lcom35.5227
# Gain of :loc5.632
# Gain of :dam6.352
# Gain of :moa7.3978
# Gain of :mfa8.1692
# Gain of :cam8.4378
# Gain of :ic9.5886
# Gain of :cbm10.653
# Gain of :amc10.7692
# ['log4j-1', 1.2074, 0.5424, 0.5811, 1.6713, 2.2563, 2.6681, 3.0965, 3.785, 4.5679, 5.2544, 5.5227, 5.632, 6.352, 7.3978, 8.1692, 8.4378, 9.5886, 10.653, 10.7692]
# -----
# Class entropy: 1.6706
# Gain of :wmc0.9523
# Gain of :dit0.6239
# Gain of :noc2.0857
# Gain of :cbo2.8929
# Gain of :rfc3.3164
# Gain of :lcom3.8832
# Gain of :ca4.9682
# Gain of :ce5.9418
# Gain of :npm6.8203
# Gain of :lcom37.2075
# Gain of :loc7.3473
# Gain of :dam8.3411
# Gain of :moa9.5907
# Gain of :mfa10.681
# Gain of :cam10.9554
# Gain of :ic12.5554
# Gain of :cbm14.0217
# Gain of :amc14.1215
# ['log4j-1.1', 1.6706, 0.9523, 0.6239, 2.0857, 2.8929, 3.3164, 3.8832, 4.9682, 5.9418, 6.8203, 7.2075, 7.3473, 8.3411, 9.5907, 10.681, 10.9554, 12.5554, 14.0217, 14.1215]
# -----
# Class entropy: 2.2859
# Gain of :wmc0.649
# Gain of :dit1.441
# Gain of :noc3.6361
# Gain of :cbo5.2206
# Gain of :rfc6.3134
# Gain of :lcom7.5529
# Gain of :ca9.2709
# Gain of :ce11.0473
# Gain of :npm12.6837
# Gain of :lcom313.653
# Gain of :loc13.9762
# Gain of :dam15.6666
# Gain of :moa17.7395
# Gain of :mfa18.9716
# Gain of :cam19.9357
# Gain of :ic22.0647
# Gain of :cbm24.0813
# Gain of :amc24.2949
# ['log4j-1.2', 2.2859, 0.649, 1.441, 3.6361, 5.2206, 6.3134, 7.5529, 9.2709, 11.0473, 12.6837, 13.653, 13.9762, 15.6666, 17.7395, 18.9716, 19.9357, 22.0647, 24.0813, 24.2949]
# -----
# Class entropy: 2.1193
# Gain of :wmc0.885
# Gain of :dit1.1214
# Gain of :noc3.0707
# Gain of :cbo4.3836
# Gain of :rfc5.3186
# Gain of :lcom6.5612
# Gain of :ca8.1073
# Gain of :ce9.5037
# Gain of :npm10.8544
# Gain of :lcom311.573
# Gain of :loc11.7834
# Gain of :dam13.416
# Gain of :moa15.2197
# Gain of :mfa16.4417
# Gain of :cam17.071
# Gain of :ic19.0828
# Gain of :cbm20.987
# Gain of :amc21.1464
# ['lucene-2', 2.1193, 0.885, 1.1214, 3.0707, 4.3836, 5.3186, 6.5612, 8.1073, 9.5037, 10.8544, 11.573, 11.7834, 13.416, 15.2197, 16.4417, 17.071, 19.0828, 20.987, 21.1464]
# -----
# Class entropy: 2.353
# Gain of :wmc0.7422
# Gain of :dit1.4951
# Gain of :noc3.665
# Gain of :cbo5.254
# Gain of :rfc6.5189
# Gain of :lcom7.9934
# Gain of :ca9.8527
# Gain of :ce11.6356
# Gain of :npm13.3143
# Gain of :lcom314.2843
# Gain of :loc14.6082
# Gain of :dam16.404
# Gain of :moa18.4163
# Gain of :mfa19.9951
# Gain of :cam20.8462
# Gain of :ic23.1286
# Gain of :cbm25.2327
# Gain of :amc25.4562
# ['lucene-2.2', 2.353, 0.7422, 1.4951, 3.665, 5.254, 6.5189, 7.9934, 9.8527, 11.6356, 13.3143, 14.2843, 14.6082, 16.404, 18.4163, 19.9951, 20.8462, 23.1286, 25.2327, 25.4562]
# -----
# Class entropy: 2.5719
# Gain of :wmc0.7499
# Gain of :dit1.694
# Gain of :noc4.0659
# Gain of :cbo5.8082
# Gain of :rfc7.1807
# Gain of :lcom8.7817
# Gain of :ca10.7784
# Gain of :ce12.7262
# Gain of :npm14.6591
# Gain of :lcom315.6849
# Gain of :loc16.1689
# Gain of :dam18.138
# Gain of :moa20.479
# Gain of :mfa22.0179
# Gain of :cam22.9581
# Gain of :ic25.393
# Gain of :cbm27.644
# Gain of :amc27.9442
# ['lucene-2.4', 2.5719, 0.7499, 1.694, 4.0659, 5.8082, 7.1807, 8.7817, 10.7784, 12.7262, 14.6591, 15.6849, 16.1689, 18.138, 20.479, 22.0179, 22.9581, 25.393, 27.644, 27.9442]
# -----
# Class entropy: 1.2924
# Gain of :wmc0.6349
# Gain of :dit0.177
# Gain of :noc1.4694
# Gain of :cbo1.9455
# Gain of :rfc2.1217
# Gain of :lcom2.8442
# Gain of :ca3.7644
# Gain of :ce4.5989
# Gain of :npm5.2437
# Gain of :lcom35.7181
# Gain of :loc5.7181
# Gain of :dam6.9006
# Gain of :moa7.8814
# Gain of :mfa8.4711
# Gain of :cam8.5452
# Gain of :ic9.6966
# Gain of :cbm10.848
# Gain of :amc10.848
# ['Nieruchomosci-1', 1.2924, 0.6349, 0.177, 1.4694, 1.9455, 2.1217, 2.8442, 3.7644, 4.5989, 5.2437, 5.7181, 5.7181, 6.9006, 7.8814, 8.4711, 8.5452, 9.6966, 10.848, 10.848]
# -----
# Class entropy: 1.5208
# Gain of :wmc0.9902
# Gain of :dit0.1383
# Gain of :noc1.5796
# Gain of :cbo2.2463
# Gain of :rfc2.3904
# Gain of :lcom2.6786
# Gain of :ca3.3837
# Gain of :ce3.9662
# Gain of :npm4.5073
# Gain of :lcom34.9247
# Gain of :loc4.9853
# Gain of :dam5.698
# Gain of :moa6.8368
# Gain of :mfa7.3848
# Gain of :cam7.5666
# Gain of :ic8.9635
# Gain of :cbm10.3456
# Gain of :amc10.4062
# ['PdfTranslator-1', 1.5208, 0.9902, 0.1383, 1.5796, 2.2463, 2.3904, 2.6786, 3.3837, 3.9662, 4.5073, 4.9247, 4.9853, 5.698, 6.8368, 7.3848, 7.5666, 8.9635, 10.3456, 10.4062]
# -----
# Class entropy: 0.8841
# Gain of :wmc0.0614
# Gain of :dit0.8149
# Gain of :noc1.6875
# Gain of :cbo2.4462
# Gain of :rfc3.1809
# Gain of :lcom3.95
# Gain of :ca4.7851
# Gain of :ce5.556
# Gain of :npm6.3946
# Gain of :lcom37.0946
# Gain of :loc7.6951
# Gain of :dam8.4975
# Gain of :moa9.3739
# Gain of :mfa10.1282
# Gain of :cam10.8173
# Gain of :ic11.6982
# Gain of :cbm12.574
# Gain of :amc13.065
# ['prop-1-4', 0.8841, 0.0614, 0.8149, 1.6875, 2.4462, 3.1809, 3.95, 4.7851, 5.556, 6.3946, 7.0946, 7.6951, 8.4975, 9.3739, 10.1282, 10.8173, 11.6982, 12.574, 13.065]
# -----
# Class entropy: 0.6493
# Gain of :wmc0.042
# Gain of :dit0.5874
# Gain of :noc1.2277
# Gain of :cbo1.8047
# Gain of :rfc2.3673
# Gain of :lcom2.9514
# Gain of :ca3.5621
# Gain of :ce4.1485
# Gain of :npm4.763
# Gain of :lcom35.3259
# Gain of :loc5.7972
# Gain of :dam6.4121
# Gain of :moa7.0587
# Gain of :mfa7.6095
# Gain of :cam8.1557
# Gain of :ic8.7927
# Gain of :cbm9.4283
# Gain of :amc9.8338
# ['prop-2-9', 0.6493, 0.042, 0.5874, 1.2277, 1.8047, 2.3673, 2.9514, 3.5621, 4.1485, 4.763, 5.3259, 5.7972, 6.4121, 7.0587, 7.6095, 8.1557, 8.7927, 9.4283, 9.8338]
# -----
# Class entropy: 0.6439
# Gain of :wmc0.041
# Gain of :dit0.5846
# Gain of :noc1.221
# Gain of :cbo1.7974
# Gain of :rfc2.3588
# Gain of :lcom2.9463
# Gain of :ca3.5635
# Gain of :ce4.149
# Gain of :npm4.7625
# Gain of :lcom35.3345
# Gain of :loc5.804
# Gain of :dam6.4147
# Gain of :moa7.053
# Gain of :mfa7.6026
# Gain of :cam8.1579
# Gain of :ic8.7924
# Gain of :cbm9.4236
# Gain of :amc9.8395
# ['prop-3-225', 0.6439, 0.041, 0.5846, 1.221, 1.7974, 2.3588, 2.9463, 3.5635, 4.149, 4.7625, 5.3345, 5.804, 6.4147, 7.053, 7.6026, 8.1579, 8.7924, 9.4236, 9.8395]
# -----
# Class entropy: 0.6004
# Gain of :wmc0.0605
# Gain of :dit0.5247
# Gain of :noc1.1191
# Gain of :cbo1.6083
# Gain of :rfc2.0763
# Gain of :lcom2.589
# Gain of :ca3.1463
# Gain of :ce3.6558
# Gain of :npm4.2173
# Gain of :lcom34.7088
# Gain of :loc5.0563
# Gain of :dam5.6169
# Gain of :moa6.2154
# Gain of :mfa6.7125
# Gain of :cam7.2
# Gain of :ic7.7935
# Gain of :cbm8.3811
# Gain of :amc8.6846
# ['prop-4-285', 0.6004, 0.0605, 0.5247, 1.1191, 1.6083, 2.0763, 2.589, 3.1463, 3.6558, 4.2173, 4.7088, 5.0563, 5.6169, 6.2154, 6.7125, 7.2, 7.7935, 8.3811, 8.6846]
# -----
# Class entropy: 0.8136
# Gain of :wmc0.0525
# Gain of :dit0.7345
# Gain of :noc1.5388
# Gain of :cbo2.2521
# Gain of :rfc2.9654
# Gain of :lcom3.7155
# Gain of :ca4.4746
# Gain of :ce5.2021
# Gain of :npm5.9698
# Gain of :lcom36.7022
# Gain of :loc7.3007
# Gain of :dam8.082
# Gain of :moa8.892
# Gain of :mfa9.5919
# Gain of :cam10.2934
# Gain of :ic11.0882
# Gain of :cbm11.8779
# Gain of :amc12.4042
# ['prop-5-347', 0.8136, 0.0525, 0.7345, 1.5388, 2.2521, 2.9654, 3.7155, 4.4746, 5.2021, 5.9698, 6.7022, 7.3007, 8.082, 8.892, 9.5919, 10.2934, 11.0882, 11.8779, 12.4042]
# -----
# Class entropy: 0.5413
# Gain of :wmc0.1089
# Gain of :dit0.4229
# Gain of :noc0.9595
# Gain of :cbo1.3743
# Gain of :rfc1.7108
# Gain of :lcom2.0557
# Gain of :ca2.5377
# Gain of :ce2.9823
# Gain of :npm3.4347
# Gain of :lcom33.7165
# Gain of :loc3.9248
# Gain of :dam4.4509
# Gain of :moa4.9379
# Gain of :mfa5.4082
# Gain of :cam5.7219
# Gain of :ic6.2394
# Gain of :cbm6.75
# Gain of :amc6.9422
# ['prop-6-452', 0.5413, 0.1089, 0.4229, 0.9595, 1.3743, 1.7108, 2.0557, 2.5377, 2.9823, 3.4347, 3.7165, 3.9248, 4.4509, 4.9379, 5.4082, 5.7219, 6.2394, 6.75, 6.9422]
# -----
# Class entropy: 0.6534
# Gain of :wmc0.2355
# Gain of :dit0.3529
# Gain of :noc0.9979
# Gain of :cbo1.4482
# Gain of :rfc1.7462
# Gain of :lcom2.3766
# Gain of :ca2.9201
# Gain of :ce3.323
# Gain of :npm3.726
# Gain of :lcom33.9343
# Gain of :loc3.9911
# Gain of :dam4.4448
# Gain of :moa5.0483
# Gain of :mfa5.4823
# Gain of :cam5.8187
# Gain of :ic6.3721
# Gain of :cbm6.8224
# Gain of :amc6.916
# ['Redaktor-1', 0.6534, 0.2355, 0.3529, 0.9979, 1.4482, 1.7462, 2.3766, 2.9201, 3.323, 3.726, 3.9343, 3.9911, 4.4448, 5.0483, 5.4823, 5.8187, 6.3721, 6.8224, 6.916]
# -----
# Class entropy: 1.0892
# Gain of :wmc0.7977
# Gain of :dit0.0672
# Gain of :noc0.9866
# Gain of :cbo1.4747
# Gain of :rfc1.6693
# Gain of :lcom1.8471
# Gain of :ca2.2292
# Gain of :ce2.7334
# Gain of :npm3.0114
# Gain of :lcom33.2046
# Gain of :loc3.2491
# Gain of :dam3.701
# Gain of :moa4.6038
# Gain of :mfa4.8583
# Gain of :cam4.959
# Gain of :ic5.9944
# Gain of :cbm7.0299
# Gain of :amc7.0911
# ['Serapion-1', 1.0892, 0.7977, 0.0672, 0.9866, 1.4747, 1.6693, 1.8471, 2.2292, 2.7334, 3.0114, 3.2046, 3.2491, 3.701, 4.6038, 4.8583, 4.959, 5.9944, 7.0299, 7.0911]
# -----
# Class entropy: 0.8748
# Gain of :wmc0.6104
# Gain of :dit0.0086
# Gain of :noc0.8834
# Gain of :cbo1.3636
# Gain of :rfc1.408
# Gain of :lcom1.6501
# Gain of :ca2.2672
# Gain of :ce2.7397
# Gain of :npm3.1619
# Gain of :lcom33.2507
# Gain of :loc3.2507
# Gain of :dam3.8905
# Gain of :moa4.4755
# Gain of :mfa4.8437
# Gain of :cam4.9443
# Gain of :ic5.7809
# Gain of :cbm6.6175
# Gain of :amc6.6175
# ['Skarbonka-1', 0.8748, 0.6104, 0.0086, 0.8834, 1.3636, 1.408, 1.6501, 2.2672, 2.7397, 3.1619, 3.2507, 3.2507, 3.8905, 4.4755, 4.8437, 4.9443, 5.7809, 6.6175, 6.6175]
# -----
# Class entropy: 1.6842
# Gain of :wmc1.2087
# Gain of :dit0.3277
# Gain of :noc1.8674
# Gain of :cbo2.3479
# Gain of :rfc2.5479
# Gain of :lcom3.3089
# Gain of :ca3.8711
# Gain of :ce4.6089
# Gain of :npm4.8711
# Gain of :lcom35.0089
# Gain of :loc5.0089
# Gain of :dam6.4231
# Gain of :moa7.53
# Gain of :mfa8.8665
# Gain of :cam9.0665
# Gain of :ic10.6155
# Gain of :cbm12.1268
# Gain of :amc12.1268
# ['SklepAGD-1', 1.6842, 1.2087, 0.3277, 1.8674, 2.3479, 2.5479, 3.3089, 3.8711, 4.6089, 4.8711, 5.0089, 5.0089, 6.4231, 7.53, 8.8665, 9.0665, 10.6155, 12.1268, 12.1268]
# -----
# Class entropy: 0.5635
# Gain of :wmc0.2612
# Gain of :dit0.2647
# Gain of :noc0.819
# Gain of :cbo1.1544
# Gain of :rfc1.2937
# Gain of :lcom1.5014
# Gain of :ca1.9606
# Gain of :ce2.2332
# Gain of :npm2.6241
# Gain of :lcom32.8622
# Gain of :loc2.8749
# Gain of :dam3.2616
# Gain of :moa3.7902
# Gain of :mfa4.1659
# Gain of :cam4.3331
# Gain of :ic4.8776
# Gain of :cbm5.411
# Gain of :amc5.4581
# ['synapse-1', 0.5635, 0.2612, 0.2647, 0.819, 1.1544, 1.2937, 1.5014, 1.9606, 2.2332, 2.6241, 2.8622, 2.8749, 3.2616, 3.7902, 4.1659, 4.3331, 4.8776, 5.411, 5.4581]
# -----
# Class entropy: 1.2534
# Gain of :wmc0.3704
# Gain of :dit0.7522
# Gain of :noc1.9818
# Gain of :cbo2.679
# Gain of :rfc3.2151
# Gain of :lcom3.9002
# Gain of :ca4.9392
# Gain of :ce5.744
# Gain of :npm6.6673
# Gain of :lcom37.2322
# Gain of :loc7.3834
# Gain of :dam8.4472
# Gain of :moa9.6054
# Gain of :mfa10.5626
# Gain of :cam11.1362
# Gain of :ic12.3635
# Gain of :cbm13.5436
# Gain of :amc13.6719
# ['synapse-1.1', 1.2534, 0.3704, 0.7522, 1.9818, 2.679, 3.2151, 3.9002, 4.9392, 5.744, 6.6673, 7.2322, 7.3834, 8.4472, 9.6054, 10.5626, 11.1362, 12.3635, 13.5436, 13.6719]
# -----
# Class entropy: 1.4467
# Gain of :wmc0.4055
# Gain of :dit0.9779
# Gain of :noc2.365
# Gain of :cbo3.301
# Gain of :rfc3.9005
# Gain of :lcom4.748
# Gain of :ca5.8844
# Gain of :ce6.8897
# Gain of :npm8.0211
# Gain of :lcom38.7046
# Gain of :loc8.921
# Gain of :dam10.1372
# Gain of :moa11.474
# Gain of :mfa12.4532
# Gain of :cam13.1362
# Gain of :ic14.5206
# Gain of :cbm15.8448
# Gain of :amc15.9538
# ['synapse-1.2', 1.4467, 0.4055, 0.9779, 2.365, 3.301, 3.9005, 4.748, 5.8844, 6.8897, 8.0211, 8.7046, 8.921, 10.1372, 11.474, 12.4532, 13.1362, 14.5206, 15.8448, 15.9538]
# -----
# Class entropy: 0.7921
# Gain of :wmc0.6042
# Gain of :dit0.031
# Gain of :noc0.8231
# Gain of :cbo1.0661
# Gain of :rfc1.2008
# Gain of :lcom1.3718
# Gain of :ca1.6868
# Gain of :ce2.009
# Gain of :npm2.4104
# Gain of :lcom32.5367
# Gain of :loc2.5791
# Gain of :dam3.3074
# Gain of :moa3.9197
# Gain of :mfa4.2311
# Gain of :cam4.4917
# Gain of :ic5.2547
# Gain of :cbm6.0178
# Gain of :amc6.1123
# ['SystemDataManagement-1', 0.7921, 0.6042, 0.031, 0.8231, 1.0661, 1.2008, 1.3718, 1.6868, 2.009, 2.4104, 2.5367, 2.5791, 3.3074, 3.9197, 4.2311, 4.4917, 5.2547, 6.0178, 6.1123]
# -----
# Class entropy: 1.5413
# Gain of :wmc0.5169
# Gain of :dit0.6604
# Gain of :noc2.2017
# Gain of :cbo3.0701
# Gain of :rfc3.4505
# Gain of :lcom4.2153
# Gain of :ca5.4248
# Gain of :ce5.9994
# Gain of :npm7.0384
# Gain of :lcom37.4244
# Gain of :loc7.5044
# Gain of :dam8.8333
# Gain of :moa10.2159
# Gain of :mfa11.1532
# Gain of :cam11.4732
# Gain of :ic12.6547
# Gain of :cbm13.8166
# Gain of :amc13.9766
# ['SzybkaFucha-1', 1.5413, 0.5169, 0.6604, 2.2017, 3.0701, 3.4505, 4.2153, 5.4248, 5.9994, 7.0384, 7.4244, 7.5044, 8.8333, 10.2159, 11.1532, 11.4732, 12.6547, 13.8166, 13.9766]
# -----
# Class entropy: 1.1994
# Gain of :wmc0.6169
# Gain of :dit0.2622
# Gain of :noc1.4487
# Gain of :cbo2.0837
# Gain of :rfc2.3874
# Gain of :lcom2.8624
# Gain of :ca3.6263
# Gain of :ce4.0749
# Gain of :npm4.9753
# Gain of :lcom35.3542
# Gain of :loc5.3542
# Gain of :dam6.1874
# Gain of :moa7.1576
# Gain of :mfa7.8569
# Gain of :cam8.1129
# Gain of :ic9.2903
# Gain of :cbm10.4521
# Gain of :amc10.4521
# ['TermoProjekt-1', 1.1994, 0.6169, 0.2622, 1.4487, 2.0837, 2.3874, 2.8624, 3.6263, 4.0749, 4.9753, 5.3542, 5.3542, 6.1874, 7.1576, 7.8569, 8.1129, 9.2903, 10.4521, 10.4521]
# -----
# Class entropy: 0.5456
# Gain of :wmc0.1902
# Gain of :dit0.3437
# Gain of :noc0.872
# Gain of :cbo1.2321
# Gain of :rfc1.455
# Gain of :lcom1.6688
# Gain of :ca2.1114
# Gain of :ce2.657
# Gain of :npm3.0448
# Gain of :lcom33.1773
# Gain of :loc3.2506
# Gain of :dam3.6606
# Gain of :moa4.0897
# Gain of :mfa4.4655
# Gain of :cam4.6051
# Gain of :ic5.1344
# Gain of :cbm5.6364
# Gain of :amc5.6755
# ['Tomcat-6.0.389418', 0.5456, 0.1902, 0.3437, 0.872, 1.2321, 1.455, 1.6688, 2.1114, 2.657, 3.0448, 3.1773, 3.2506, 3.6606, 4.0897, 4.4655, 4.6051, 5.1344, 5.6364, 5.6755]
# -----
# Class entropy: 2.3843
# Gain of :wmc0.8427
# Gain of :dit1.449
# Gain of :noc3.6797
# Gain of :cbo5.2265
# Gain of :rfc6.2338
# Gain of :lcom7.6606
# Gain of :ca9.5036
# Gain of :ce11.0825
# Gain of :npm12.7265
# Gain of :lcom313.909
# Gain of :loc14.2042
# Gain of :dam16.1367
# Gain of :moa18.2151
# Gain of :mfa19.8356
# Gain of :cam20.6111
# Gain of :ic22.9361
# Gain of :cbm25.2425
# Gain of :amc25.6459
# ['velocity-1.5', 2.3843, 0.8427, 1.449, 3.6797, 5.2265, 6.2338, 7.6606, 9.5036, 11.0825, 12.7265, 13.909, 14.2042, 16.1367, 18.2151, 19.8356, 20.6111, 22.9361, 25.2425, 25.6459]
# -----
# Class entropy: 1.686
# Gain of :wmc0.6589
# Gain of :dit0.9411
# Gain of :noc2.5397
# Gain of :cbo3.5235
# Gain of :rfc4.2676
# Gain of :lcom5.2811
# Gain of :ca6.5417
# Gain of :ce7.5965
# Gain of :npm8.6552
# Gain of :lcom39.4995
# Gain of :loc9.7593
# Gain of :dam11.0706
# Gain of :moa12.5386
# Gain of :mfa13.682
# Gain of :cam14.1224
# Gain of :ic15.7495
# Gain of :cbm17.3406
# Gain of :amc17.6221
# ['velocity-1.6.1', 1.686, 0.6589, 0.9411, 2.5397, 3.5235, 4.2676, 5.2811, 6.5417, 7.5965, 8.6552, 9.4995, 9.7593, 11.0706, 12.5386, 13.682, 14.1224, 15.7495, 17.3406, 17.6221]
# -----
# Class entropy: 0.9995
# Gain of :wmc0.3375
# Gain of :dit0.5356
# Gain of :noc1.4566
# Gain of :cbo1.8856
# Gain of :rfc2.2933
# Gain of :lcom2.724
# Gain of :ca3.4438
# Gain of :ce4.1234
# Gain of :npm4.8299
# Gain of :lcom35.2348
# Gain of :loc5.3054
# Gain of :dam6.2529
# Gain of :moa7.1039
# Gain of :mfa7.6716
# Gain of :cam7.918
# Gain of :ic8.8739
# Gain of :cbm9.8183
# Gain of :amc10.0428
# ['WorkFlow-1', 0.9995, 0.3375, 0.5356, 1.4566, 1.8856, 2.2933, 2.724, 3.4438, 4.1234, 4.8299, 5.2348, 5.3054, 6.2529, 7.1039, 7.6716, 7.918, 8.8739, 9.8183, 10.0428]
# -----
# Class entropy: 2.3083
# Gain of :wmc1.483
# Gain of :dit0.5891
# Gain of :noc2.8045
# Gain of :cbo3.402
# Gain of :rfc3.5131
# Gain of :lcom3.8884
# Gain of :ca4.8884
# Gain of :ce5.6389
# Gain of :npm7.3757
# Gain of :lcom37.5979
# Gain of :loc7.5979
# Gain of :dam8.7812
# Gain of :moa10.3878
# Gain of :mfa11.5828
# Gain of :cam11.805
# Gain of :ic14.0204
# Gain of :cbm16.2358
# Gain of :amc16.2358
# ['WspomaganiePI-1', 2.3083, 1.483, 0.5891, 2.8045, 3.402, 3.5131, 3.8884, 4.8884, 5.6389, 7.3757, 7.5979, 7.5979, 8.7812, 10.3878, 11.5828, 11.805, 14.0204, 16.2358, 16.2358]
# -----
# Class entropy: 0.8231
# Gain of :wmc0.2219
# Gain of :dit0.5349
# Gain of :noc1.2528
# Gain of :cbo1.8523
# Gain of :rfc2.3437
# Gain of :lcom2.8856
# Gain of :ca3.5939
# Gain of :ce4.248
# Gain of :npm4.9291
# Gain of :lcom35.4153
# Gain of :loc5.7149
# Gain of :dam6.3833
# Gain of :moa7.1436
# Gain of :mfa7.6987
# Gain of :cam8.067
# Gain of :ic8.8651
# Gain of :cbm9.5943
# Gain of :amc9.8804
# ['xerces-1.2.0', 0.8231, 0.2219, 0.5349, 1.2528, 1.8523, 2.3437, 2.8856, 3.5939, 4.248, 4.9291, 5.4153, 5.7149, 6.3833, 7.1436, 7.6987, 8.067, 8.8651, 9.5943, 9.8804]
# -----
# Class entropy: 0.9578
# Gain of :wmc0.3943
# Gain of :dit0.4777
# Gain of :noc1.3419
# Gain of :cbo1.9794
# Gain of :rfc2.4355
# Gain of :lcom2.8984
# Gain of :ca3.615
# Gain of :ce4.2622
# Gain of :npm4.9264
# Gain of :lcom35.2332
# Gain of :loc5.3755
# Gain of :dam5.938
# Gain of :moa6.7339
# Gain of :mfa7.252
# Gain of :cam7.6181
# Gain of :ic8.4356
# Gain of :cbm9.1695
# Gain of :amc9.2635
# ['xerces-1.3.0', 0.9578, 0.3943, 0.4777, 1.3419, 1.9794, 2.4355, 2.8984, 3.615, 4.2622, 4.9264, 5.2332, 5.3755, 5.938, 6.7339, 7.252, 7.6181, 8.4356, 9.1695, 9.2635]
# -----
# Class entropy: 2.8245
# Gain of :wmc0.8676
# Gain of :dit1.5734
# Gain of :noc4.1703
# Gain of :cbo5.7468
# Gain of :rfc7.4433
# Gain of :lcom9.0861
# Gain of :ca11.0694
# Gain of :ce12.8049
# Gain of :npm14.8657
# Gain of :lcom316.3852
# Gain of :loc17.1537
# Gain of :dam19.3521
# Gain of :moa21.7343
# Gain of :mfa23.3619
# Gain of :cam24.5111
# Gain of :ic27.0473
# Gain of :cbm29.4064
# Gain of :amc30.0825
# ['xerces-1.4.4', 2.8245, 0.8676, 1.5734, 4.1703, 5.7468, 7.4433, 9.0861, 11.0694, 12.8049, 14.8657, 16.3852, 17.1537, 19.3521, 21.7343, 23.3619, 24.5111, 27.0473, 29.4064, 30.0825]
# -----
# Class entropy: 1.7612
# Gain of :wmc0.7117
# Gain of :dit0.9014
# Gain of :noc2.4603
# Gain of :cbo3.3884
# Gain of :rfc4.2738
# Gain of :lcom5.3773
# Gain of :ca6.5491
# Gain of :ce7.6697
# Gain of :npm8.8221
# Gain of :lcom39.5436
# Gain of :loc9.8849
# Gain of :dam11.1687
# Gain of :moa12.6019
# Gain of :mfa13.8214
# Gain of :cam14.4914
# Gain of :ic16.1464
# Gain of :cbm17.6027
# Gain of :amc18.0787
# ['xerces-init', 1.7612, 0.7117, 0.9014, 2.4603, 3.3884, 4.2738, 5.3773, 6.5491, 7.6697, 8.8221, 9.5436, 9.8849, 11.1687, 12.6019, 13.8214, 14.4914, 16.1464, 17.6027, 18.0787]
# -----
# Class entropy: 1.5814
# Gain of :wmc1.3485
# Gain of :dit0.0962
# Gain of :noc1.4852
# Gain of :cbo1.9116
# Gain of :rfc1.9806
# Gain of :lcom2.1305
# Gain of :ca2.7498
# Gain of :ce3.4311
# Gain of :npm4.3677
# Gain of :lcom34.4921
# Gain of :loc4.5611
# Gain of :dam5.8553
# Gain of :moa6.8411
# Gain of :mfa7.4144
# Gain of :cam7.5953
# Gain of :ic9.1767
# Gain of :cbm10.7582
# Gain of :amc10.8272
# ['Zuzel-1', 1.5814, 1.3485, 0.0962, 1.4852, 1.9116, 1.9806, 2.1305, 2.7498, 3.4311, 4.3677, 4.4921, 4.5611, 5.8553, 6.8411, 7.4144, 7.5953, 9.1767, 10.7582, 10.8272]
# -----

# %%
col=list(data.columns[3:21].values)
col.insert(0,"project name")
col.insert(1,"class-entropy")
newDf = pd.DataFrame(columns=col, data=dfList)
newDf.head()
# Out:
#   project name  class-entropy     wmc     dit     noc     cbo     rfc    lcom  \
# 0      ant-1.3         0.8645  0.4248  0.3744  1.1848  1.6589  1.8447  2.1333
# 1      ant-1.4         0.9181  0.2178  0.6290  1.4844  2.0975  2.5280  3.0553
# 2      ant-1.5         0.5466  0.2266  0.2907  0.8052  1.1776  1.3283  1.4814
# 3      ant-1.6         1.3270  0.5754  0.6684  1.9254  2.7281  3.1831  3.6780
# 4      ant-1.7         1.2060  0.4436  0.7100  1.8577  2.7091  3.2300  3.6917
#
#        ca      ce     npm   lcom3     loc     dam     moa     mfa     cam  \
# 0  2.6906  3.2264  3.6839  3.7471  3.7791  4.4177  5.1634  5.6333  5.7188
# 1  3.8332  4.4812  5.1743  5.5580  5.6949  6.4864  7.2834  7.6674  7.9923
# 2  1.9566  2.2880  2.6541  2.7800  2.8414  3.2051  3.6751  3.8639  3.9936
# 3  4.7069  5.5978  6.4245  6.7012  6.7980  7.7778  8.8935  9.5360  9.8482
# 4  4.7090  5.5722  6.4340  6.7505  6.9255  7.8231  8.8682  9.4621  9.7981
#
#         ic      cbm      amc
# 0   6.5095   7.2728   7.2888
# 1   8.8549   9.6956   9.7925
# 2   4.4866   4.9477   4.9477
# 3  11.1112  12.3082  12.3911
# 4  10.9611  12.0857  12.1802
